# %%
x = 17
print(x)
# Out:
# 17

# %%
type(x)
# Out:
# int

# %%
y = 'es krim vanila'

print (y)

type (y)
# Out:
# es krim vanila
# str

# %%
y = 'es krim vanila'

Y = 'es krim coklat'

print(y)
print(Y)
# Out:
# es krim vanila
# es krim coklat

# %%
x,y,z = 'es krim vanila', 'es krim coklat', 'es krim stroberi'

print(x)
print(y)
print(z)
# Out:
# es krim vanila
# es krim coklat
# es krim stroberi

# %%
x = y = z = 'es krim alpukat'

print(x)
print(y)
print(z)
# Out:
# es krim alpukat
# es krim alpukat
# es krim alpukat

# %%
es_krim = ['es krim vanila', 'es krim coklat', 'es krim stroberi']

x,y,z = es_krim

print(es_krim)
print(x)
print(y)
print(z)
type(es_krim)
# Out:
# ['es krim vanila', 'es krim coklat', 'es krim stroberi']
# es krim vanila
# es krim coklat
# es krim stroberi
# list

# %%
#Camel Case

#Test Variabel Case

testVariabelCase = 'es krim vanila'

print(testVariabelCase)
# Out:
# es krim vanila

# %%
#Pascal Case

#Test Variabel Case

TestVariableCase = 'es krim vanila'

print(TestVariableCase)
# Out:
# es krim vanila

# %%
#Snake Case

#Test Variabel Case

test_variable_case = 'es krim vanila'

print(test_variable_case)
# Out:
# es krim vanila

# %%
testVariableCase = 'es krim vanila'
Test_variable_Case = 'es krim vanila'
TestvariableCase = 'es krim vanila'

# %%
2TestVariableCase = 'es krim vanila'
2_tESTVariableCase = 'es krim vanila'

# %%
y = 3+2

print(y)
# Out:
# 5

# %%
x='play chess'
y='like'
z='magnus carlsen'

print(x + y + z)
print(x,y,z)
# Out:
# play chesslikemagnus carlsen
# play chess like magnus carlsen

# %%
x='magnus carlsen'
y=21
z='champions of the world'

print(x ,y, z)
# Out:
# magnus carlsen 21 champions of the world
