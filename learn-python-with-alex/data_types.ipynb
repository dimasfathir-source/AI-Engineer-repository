# %%
type(12)
# Out:
# int

# %%
type(-12)
# Out:
# int

# %%
type(3.14 + 500)
# Out:
# float

# %%
type("Hello, World!")
# Out:
# str

# %%
'Single Quote'
"Double Quote"
"""Triple Quote"""
# Out:
# 'Triple Quote'

# %%
"""Magnus carlsen pemain catur terhebat sepanjang masa,
baru saja menjuarai esport world cup 2026"""
# Out:
# 'Magnus carlsen pemain catur terhebat sepanjang masa,\nbaru saja menjuarai esport world cup 2026'

# %%
'Ini bagus'
"Ini adalah 'kemeja' paling bagus"
"""ini adalah kemeja dan "baju baru yang sangat bagus" hahaha"""
# Out:
# 'ini adalah kemeja dan "baju baru yang sangat bagus" hahaha'

# %%
x = 'Bang jago bang bang'

# %%
print(x[:5])
# Out:
# Bang

# %%
type(122 + 5j)
# Out:
# complex

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
1 < 5
# Out:
# True

# %%
7 > 100
# Out:
# False

# %%
[1, 2, 3, 4, 5]
# Out:
# [1, 2, 3, 4, 5]

# %%
['es krim coklat', 'es krim vanila', 'es krim stroberi']
# Out:
# ['es krim coklat', 'es krim vanila', 'es krim stroberi']

# %%
es_krim = ['es krim coklat', 'es krim vanila', 'es krim stroberi']
print(es_krim)
# Out:
# ['es krim coklat', 'es krim vanila', 'es krim stroberi']

# %%
type(es_krim)
# Out:
# list

# %%
print(es_krim[2])
# Out:
# es krim stroberi

# %%
tupple_scoups = (1,2,3,3,2,1)

# %%
type(tupple_scoups)
# Out:
# tuple

# %%
set = {1, 2, 3, 4, 5}

# %%
type(set)
# Out:
# set

# %%
daily_im = {1,2,3,4,5,6,7}
print(daily_im)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
daily_u = {4,5,6,7,8,9}
print(daily_u)
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
print(daily_im & daily_u)
# Out:
# {4, 5, 6, 7}

# %%
print(daily_im | daily_u)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
print(daily_im - daily_u)
# Out:
# {1, 2, 3}

# %%
dictionaries = {'name': 'Dimas', 'age': 20, 'address': 'Jakarta'}

# %%
print(dictionaries)
print(dictionaries['name'])
# Out:
# {'name': 'Dimas', 'age': 20, 'address': 'Jakarta'}
# Dimas

# %%
dictionaries.keys()
# Out:
# dict_keys(['name', 'age', 'address'])

# %%
dictionaries.values()
# Out:
# dict_values(['Dimas', 20, 'Jakarta'])

# %%
dictionaries.items()
# Out:
# dict_items([('name', 'Dimas'), ('age', 20), ('address', 'Jakarta')])

# %%
dictionaries['name'] = 'Muhammad Dimas Alfathir'
dictionaries['age'] = 23

# %%
print(dictionaries)
# Out:
# {'name': 'Muhammad Dimas Alfathir', 'age': 23, 'address': 'Jakarta'}
